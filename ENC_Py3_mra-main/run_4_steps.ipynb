# %%
# %run 1.Elimination.py
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# ~\anaconda3\envs\gds\envs\myenv\lib\site-packages\IPython\core\magics\execution.py in run(self, parameter_s, runner, file_finder)
#     702             fpath = arg_lst[0]
# --> 703             filename = file_finder(fpath)
#     704         except IndexError:
#
# ~\anaconda3\envs\gds\envs\myenv\lib\site-packages\IPython\utils\path.py in get_py_filename(name, force_win32)
#     108     else:
# --> 109         raise IOError('File `%r` not found.' % name)
#     110
#
# OSError: File `'1.Elimination.py'` not found.
#
# During handling of the above exception, another exception occurred:
#
# Exception                                 Traceback (most recent call last)
# <ipython-input-2-355d52526521> in <module>
# ----> 1 get_ipython().run_line_magic('run', '1.Elimination.py')
#
# ...

# %%
# %run 2.Categorisation.py

# %%
# %run 3.Coarse_adj.py
# Out:
# [[2.54980e+04 1.13200e+03 1.05600e+03 1.02650e+04 3.23000e+02 3.29900e+03
#   4.93000e+02 0.00000e+00 0.00000e+00 1.00000e+01 0.00000e+00 0.00000e+00
#   4.20760e+04]
#  [1.00000e+00 1.08190e+04 1.00000e+01 2.00000e+00 0.00000e+00 0.00000e+00
#   0.00000e+00 4.00000e+00 0.00000e+00 0.00000e+00 0.00000e+00 0.00000e+00
#   1.08360e+04]
#  [1.48000e+02 1.16000e+02 1.41300e+03 2.84000e+02 1.40000e+01 6.47000e+02
#   1.81000e+02 2.30000e+01 0.00000e+00 0.00000e+00 3.90000e+01 0.00000e+00
#   2.86500e+03]
#  [6.10300e+03 7.91400e+03 5.21000e+02 1.59140e+04 0.00000e+00 1.81500e+03
#   3.00000e+02 0.00000e+00 0.00000e+00 1.70000e+01 0.00000e+00 0.00000e+00
#   3.25840e+04]
#  [2.92000e+02 7.50000e+01 3.00000e+00 8.00000e+01 7.61000e+02 2.00000e+01
#   3.00000e+00 0.00000e+00 0.00000e+00 0.00000e+00 0.00000e+00 0.00000e+00
#   1.23400e+03]
#  [4.58000e+02 1.41000e+02 5.07000e+02 9.03000e+02 1.00000e+00 5.60300e+03
#   3.00000e+00 6.10000e+01 0.00000e+00 4.50000e+01 0.00000e+00 0.00000e+00
# ...

# %%
# %run 4.Fine_adj.py
# Out:
# [[2.54980e+04 1.13200e+03 1.05600e+03 1.02650e+04 3.23000e+02 3.29900e+03
#   4.93000e+02 0.00000e+00 0.00000e+00 1.00000e+01 0.00000e+00 0.00000e+00
#   4.20760e+04]
#  [1.00000e+00 1.08190e+04 1.00000e+01 2.00000e+00 0.00000e+00 0.00000e+00
#   0.00000e+00 4.00000e+00 0.00000e+00 0.00000e+00 0.00000e+00 0.00000e+00
#   1.08360e+04]
#  [1.48000e+02 1.16000e+02 1.41300e+03 2.84000e+02 1.40000e+01 6.47000e+02
#   1.81000e+02 2.30000e+01 0.00000e+00 0.00000e+00 3.90000e+01 0.00000e+00
#   2.86500e+03]
#  [6.10300e+03 7.91400e+03 5.21000e+02 1.59140e+04 0.00000e+00 1.81500e+03
#   3.00000e+02 0.00000e+00 0.00000e+00 1.70000e+01 0.00000e+00 0.00000e+00
#   3.25840e+04]
#  [2.92000e+02 7.50000e+01 3.00000e+00 8.00000e+01 7.61000e+02 2.00000e+01
#   3.00000e+00 0.00000e+00 0.00000e+00 0.00000e+00 0.00000e+00 0.00000e+00
#   1.23400e+03]
#  [4.58000e+02 1.41000e+02 5.07000e+02 9.03000e+02 1.00000e+00 5.60300e+03
#   3.00000e+00 6.10000e+01 0.00000e+00 4.50000e+01 0.00000e+00 0.00000e+00
# ...
